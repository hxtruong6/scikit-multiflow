# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/Users/xuantruong/Documents/JAIST/scikit-multiflow/tests/evaluation/result/evaluation_results.csv')

# Display the contents of the DataFrame
print(df.info())
print("-"*50)
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Dataset                    196 non-null    object
#  1   Model                      196 non-null    object
#  2   Predict Function of Model  196 non-null    object
#  3   Metric Function            196 non-null    object
#  4   Score                      196 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 7.8+ KB
# None
# --------------------------------------------------
#       Dataset               Model Predict Function of Model  \
# 0    emotions  LogisticRegression      Predict Hamming Loss
# 1    emotions  LogisticRegression      Predict Hamming Loss
# 2    emotions  LogisticRegression      Predict Hamming Loss
# 3    emotions  LogisticRegression      Predict Hamming Loss
# 4    emotions  LogisticRegression      Predict Hamming Loss
# ..        ...                 ...                       ...
# 191  emotions  AdaBoostClassifier          Predict Fmeasure
# 192  emotions  AdaBoostClassifier          Predict Fmeasure
# 193  emotions  AdaBoostClassifier          Predict Fmeasure
# 194  emotions  AdaBoostClassifier          Predict Fmeasure
# 195  emotions  AdaBoostClassifier          Predict Fmeasure
#
#                Metric Function    Score
# 0                 Hamming Loss  0.22525
# 1              Subset Accuracy  0.22772
# 2              Precision Score  0.53133
# 3    Negative Predictive Value  0.89422
# 4                 Recall Score  0.71141
# ..                         ...      ...
# 191            Precision Score  1.00000
# 192  Negative Predictive Value  0.00246
# 193               Recall Score  0.32975
# 194                 Markedness  0.50123
# 195               F-beta Score  0.49596
#
# [196 rows x 5 columns]

# %%
df
# Out:
#       Dataset               Model Predict Function of Model  \
# 0    emotions  LogisticRegression      Predict Hamming Loss
# 1    emotions  LogisticRegression      Predict Hamming Loss
# 2    emotions  LogisticRegression      Predict Hamming Loss
# 3    emotions  LogisticRegression      Predict Hamming Loss
# 4    emotions  LogisticRegression      Predict Hamming Loss
# ..        ...                 ...                       ...
# 191  emotions  AdaBoostClassifier          Predict Fmeasure
# 192  emotions  AdaBoostClassifier          Predict Fmeasure
# 193  emotions  AdaBoostClassifier          Predict Fmeasure
# 194  emotions  AdaBoostClassifier          Predict Fmeasure
# 195  emotions  AdaBoostClassifier          Predict Fmeasure
#
#                Metric Function    Score
# 0                 Hamming Loss  0.22525
# 1              Subset Accuracy  0.22772
# 2              Precision Score  0.53133
# 3    Negative Predictive Value  0.89422
# 4                 Recall Score  0.71141
# ..                         ...      ...
# 191            Precision Score  1.00000
# 192  Negative Predictive Value  0.00246
# 193               Recall Score  0.32975
# 194                 Markedness  0.50123
# 195               F-beta Score  0.49596
#
# [196 rows x 5 columns]
